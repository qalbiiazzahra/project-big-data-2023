# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
hunger_index = pd.read_csv("/content/globalHungerIndex.csv")
under_weight = pd.read_csv("/content/childrenOfUnderweight.csv")
wasting = pd.read_csv("/content/weightTooLowForTheirHeightWasting.csv")
stunting = pd.read_csv("/content/youngerThanFiveWhoSufferFromStunting.csv")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
hunger_index.head()
# Out:
#         Entity Code  Year  Global Hunger Index (2021) 411773-annotations
# 0  Afghanistan  AFG  2000                        50.9                NaN
# 1  Afghanistan  AFG  2006                        42.7                NaN
# 2  Afghanistan  AFG  2012                        34.3                NaN
# 3  Afghanistan  AFG  2021                        28.3                NaN
# 4      Albania  ALB  2000                        20.7                NaN

# %%
under_weight.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1997
# 1  Afghanistan  AFG  2004
# 2  Afghanistan  AFG  2013
# 3  Afghanistan  AFG  2018
# 4      Albania  ALB  1997
#
#    Prevalence of underweight, weight for age (% of children under 5)
# 0                                          44.900002
# 1                                          32.900002
# 2                                          24.600000
# 3                                          19.100000
# 4                                           7.100000

# %%
stunting.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1997
# 1  Afghanistan  AFG  2004
# 2  Afghanistan  AFG  2013
# 3  Afghanistan  AFG  2018
# 4      Albania  ALB  1997
#
#    Prevalence of stunting, height for age (% of children under 5)
# 0                                          53.200001
# 1                                          59.299999
# 2                                          40.400002
# 3                                          38.200001
# 4                                          20.400000

# %%
wasting.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1997
# 1  Afghanistan  AFG  2004
# 2  Afghanistan  AFG  2013
# 3  Afghanistan  AFG  2018
# 4      Albania  ALB  1997
#
#    Prevalence of wasting, weight for height (% of children under 5)
# 0                                          18.200001
# 1                                           8.600000
# 2                                           9.500000
# 3                                           5.100000
# 4                                           8.100000

# %% [markdown]
# Preprocessing

# %%
hunger_index2=hunger_index.pivot(index='Entity', columns='Year', values='Global Hunger Index (2021)')
hunger_index2=hunger_index2.reset_index()
hunger_index2.head()
# Out:
# Year       Entity  2000  2006  2012  2021
# 0     Afghanistan  50.9  42.7  34.3  28.3
# 1         Albania  20.7  15.9   8.8   6.2
# 2         Algeria  14.5  11.7   8.9   6.9
# 3          Angola  65.0  46.9  27.8  26.0
# 4       Argentina   6.4   5.6   5.2   5.3

# %% [markdown]
# Analysis

# %%
col=[2000,2006,2012,2021]
fig = plt.figure(figsize=(15,5))

for i in range(len(col)):
    plt.subplot(1,4,i+1)
    plt.title(col[i])
    sns.distplot(hunger_index2,x=hunger_index2[col[i]])
    plt.xlim([0,75])
    plt.ylim([0,0.06])
plt.tight_layout()
plt.show()

# %%
col=[2000,2006,2012,2021]
plt.figure(figsize=(10, 5))
for i in col:
    sns.distplot(hunger_index2[i],axlabel='Hunger Index')

# %%
hunger_index2[hunger_index2[2000]>=50].sort_values(by=2000, ascending=True).plot.barh(y=2000,x='Entity',legend=False);

# %%
hunger_index2[hunger_index2[2021]>=50].sort_values(by=2000, ascending=True).plot.barh(y=2000,x='Entity',legend=False);

# %%
list=['Angola','Somalia','Sierra Leone','Ethiopia','Afganistan','Chad',"Democratic Republic of Congo"]

# %%
hunger_index_7=hunger_index[(hunger_index['Entity']=='Angola')|(hunger_index['Entity']=='Somalia')|(hunger_index['Entity']=='Sierra Leone')|
               (hunger_index['Entity']=='Afganistan')|(hunger_index['Entity']=='Ethiopia')|(hunger_index['Entity']=='Chad')|
               (hunger_index['Entity']=='Democratic Republic of Congo')]

# %%
sns.lineplot(data=hunger_index_7, x="Year", y="Global Hunger Index (2021)", hue="Entity")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
under_weight_7=under_weight[(under_weight['Entity']=='Angola')|(under_weight['Entity']=='Somalia')|(under_weight['Entity']=='Sierra Leone')|
               (under_weight['Entity']=='Afganistan')|(under_weight['Entity']=='Ethiopia')|(under_weight['Entity']=='Chad')|
               (under_weight['Entity']=='Democratic Republic of Congo')]

# %%
sns.lineplot(data=under_weight_7, x="Year", y="Prevalence of underweight, weight for age (% of children under 5)", hue="Entity")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
stunting_7=stunting[(stunting['Entity']=='Angola')|(stunting['Entity']=='Somalia')|(stunting['Entity']=='Sierra Leone')|
               (stunting['Entity']=='Afganistan')|(stunting['Entity']=='Ethiopia')|(stunting['Entity']=='Chad')|
               (stunting['Entity']=='Democratic Republic of Congo')]

# %%
sns.lineplot(data=stunting_7, x="Year", y="Prevalence of stunting, height for age (% of children under 5)", hue="Entity")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);

# %%
wasting_7=wasting[(wasting['Entity']=='Angola')|(wasting['Entity']=='Somalia')|(wasting['Entity']=='Sierra Leone')|
               (wasting['Entity']=='Afganistan')|(wasting['Entity']=='Ethiopia')|(wasting['Entity']=='Chad')|
               (wasting['Entity']=='Democratic Republic of Congo')]

# %%
sns.lineplot(data=wasting_7, x="Year", y="Prevalence of wasting, weight for height (% of children under 5)", hue="Entity")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0);
